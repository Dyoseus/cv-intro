# %%
import apriltags
import LincolnLabsSecretSauce as lane_detection_Emily
import lane_following as lane_following_Emily
import cv2
import matplotlib.pyplot as plt

# %%
img =  cv2.imread('5.jpg')
cropped_image = img[20:360, 30:640]

# %%
lines = lane_detection_Emily.detect_lines(cropped_image)
lane_detection_Emily.draw_lines(cropped_image, lines)
plt.imshow(cv2.cvtColor(lane_detection_Emily.draw_lines(cropped_image, lines), cv2.COLOR_BGR2RGB))
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, *, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, interpolation_stage=None, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>
