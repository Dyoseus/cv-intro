# %%
import cv2
from matplotlib import pyplot as plt
import LincolnLabsSecretSauce as llss

# %%
IP_ADDRESS = "192.168.1.102"

# %%
vcap = cv2.VideoCapture(f"rtsp://{IP_ADDRESS}:8554/rovcam")

img = None

MAX_RETRY = 100
count = 0
while count < MAX_RETRY:
    count += 1
    # Obtain the frame
    ret, frame = vcap.read()

    # Check frame was received successfully
    if ret:
        # got a frame, close the cap and return the frame
        print(" got a frame ")
        img = frame
        vcap.release()

vcap.release()

# %%
type(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(img)
#
# NameError: name 'img' is not defined

# %%
plt.imshow(img)

# %%
lines = llss.detect_lines(img, 50, 150, 3, 170, 15)

# %%
#plt.imshow(cv2.cvtColor(llss.draw_lines(img, lines), cv2.COLOR_BGR2RGB))

# %%
lanes = llss.detect_lanes(lines)

# %%
plt.imshow(cv2.cvtColor(llss.draw_lanes(img, lanes), cv2.COLOR_BGR2RGB))
